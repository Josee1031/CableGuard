# %%
from roboflow import Roboflow
rf = Roboflow(api_key="THGcdx5QNTyJ7gyKZncw")
project = rf.workspace("roboflow-100").project("cable-damage")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.130, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to cable-damage-2 in yolov8:: 100%|█| 2648/2648 [

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/Users/jose/Downloads/cable-damage/cable-damage-2/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# ...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 11.6MB/s]
# New https://pypi.org/project/ultralytics/8.0.131 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.130 🚀 Python-3.10.9 torch-2.0.1 CPU
# ...
